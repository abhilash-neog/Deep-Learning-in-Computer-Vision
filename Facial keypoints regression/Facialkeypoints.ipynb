# %% [markdown]
# ## Facial keypoints detection
#
# In this task you will create facial keypoint detector based on CNN regressor.
#
#
# ![title](example.png)

# %% [markdown]
# ### Load and preprocess data

# %% [markdown]
# Script `get_data.py` unpacks data — images and labelled points. 6000 images are located in `images` folder and keypoint coordinates are in `gt.csv` file. Run the cell below to unpack data.

# %%
from get_data import unpack
unpack('facial-keypoints-data.zip')

# %% [markdown]
# Now you have to read `gt.csv` file and images from `images` dir. File `gt.csv` contains header and ground truth points for every image in `images` folder. It has 29 columns. First column is a filename and next 28 columns are `x` and `y` coordinates for 14 facepoints. We will make following preprocessing:
# 1. Scale all images to resolution $100 \times 100$ pixels.
# 2. Scale all coordinates to range $[-0.5; 0.5]$. To obtain that, divide all x's by width (or number of columns) of image, and divide all y's by height (or number of rows) of image and subtract 0.5 from all values.
#
# Function `load_imgs_and_keypoint` should return a tuple of two numpy arrays: `imgs` of shape `(N, 100, 100, 3)`, where `N` is the number of images and `points` of shape `(N, 28)`.

# %%
### Useful routines for preparing data
from os.path import join
from skimage.color import gray2rgb
from skimage.io import imread
from skimage.transform import resize
import pandas as pd
import numpy as np


def load_imgs_and_keypoints(dirname='facial-keypoints'):
    # Write your code for loading images and points here
    imgpath = 'data/images'
    keypath = 'data/'
    df = pd.read_csv(keypath+'gt.csv')
    df1 = df.iloc[:,1:].astype('float64')
    images = []
    for i in range(df.shape[0]):
        img = imread(imgpath+'/'+df.iloc[i,0])
        ht,wt = img.shape[0], img.shape[1]
        img_resized = gray2rgb(resize(img, (100,100)))
        images.append(img_resized)
        df1.iloc[i,0:][::2].values[:] = (df1.iloc[i,0:][::2].values[:]/wt) - 0.5
        df1.iloc[i,1:][::2].values[:] = (df1.iloc[i,1:][::2].values[:]/ht) - 0.5

    return np.stack(images), df1.to_numpy()

imgs, points = load_imgs_and_keypoints()

# %%
# Example of output
# %matplotlib inline
from skimage.io import imshow
imshow(imgs[0])
points[0]
# Out:
# array([-0.30534351, -0.30534351, -0.01526718, -0.27099237,  0.14503817,
#        -0.2519084 ,  0.27480916, -0.30152672, -0.24045802, -0.20610687,
#        -0.17557252, -0.21374046, -0.08015267, -0.1870229 ,  0.11068702,
#        -0.16793893,  0.15267176, -0.19847328,  0.23664122, -0.17938931,
#         0.09541985,  0.04961832, -0.14885496,  0.16412214,  0.03435115,
#         0.1870229 ,  0.14122137,  0.18320611])

# %% [markdown]
# ### Visualize data

# %% [markdown]
# Let's prepare a function to visualize points on image. Such function obtains two arguments: an image and a vector of points' coordinates and draws points on image (just like first image in this notebook).

# %%
import matplotlib.pyplot as plt
# Circle may be useful for drawing points on face
# See matplotlib documentation for more info
from matplotlib.patches import Circle

def visualize_points(img, points):
    # Write here function which obtains image and normalized
    # coordinates and visualizes points on image
    
    x = (points[0::2]+0.5)*100
    y = (points[1::2]+0.5)*100
    fig, ax = plt.subplots()
    im = ax.imshow(img)
    for i in range(14):
        plt.plot(x[i], y[i], 'o', color='r', markersize = 4.1)
    
    plt.show()
    
visualize_points(imgs[1], points[1])

# %% [markdown]
# ### Train/val split

# %% [markdown]
# Run the following code to obtain train/validation split for training neural network.

# %%
from sklearn.model_selection import train_test_split
imgs_train, imgs_val, points_train, points_val = train_test_split(imgs, points, test_size=0.1)

# %% [markdown]
# ### Simple data augmentation

# %% [markdown]
# For better training we will use simple data augmentation — flipping an image and points. Implement function flip_img which flips an image and its' points. Make sure that points are flipped correctly! For instance, points on right eye now should be points on left eye (i.e. you have to mirror coordinates and swap corresponding points on the left and right sides of the face). VIsualize an example of original and flipped image.

# %%
import cv2
def flip_img(img, points):
    # Write your code for flipping here
    flip_img = cv2.flip(img,1)#flipping around y-axis
    flip_points = np.copy(points)
    flip_points[0::2] = -1*flip_points[0::2]#since flipped around y-axis. y values remain constant
    return flip_img,flip_points

f_img, f_points = flip_img(imgs[1], points[1])
visualize_points(f_img, f_points)

# %% [markdown]
# Time to augment our training sample. Apply flip to every image in training sample. As a result you should obtain two arrays: `aug_imgs_train` and `aug_points_train` which contain original images and points along with flipped ones.

# %%
# Write your code here
aug_imgs_ = []
aug_points_ = []
for i in range(imgs_train.shape[0]):
    aug_imgs_.append(imgs_train[i])
    aug_points_.append(points_train[i])
    _img, _points = flip_img(imgs_train[i], points_train[i])
    aug_imgs_.append(_img)
    aug_points_.append(_points)
aug_imgs_train = np.array(aug_imgs_)
aug_points_train = np.array(aug_points_)
print(aug_imgs_train.shape, aug_points_train.shape)
# Out:
# (10800, 100, 100, 3) (10800, 28)

# %%
visualize_points(aug_imgs_train[0], aug_points_train[2])

# %%
visualize_points(aug_imgs_train[1], aug_points_train[3])

# %% [markdown]
# ### Network architecture and training
#
# Now let's define neural network regressor. It will have 28 outputs, 2 numbers per point. The precise architecture is up to you. We recommend to add 2-3 (`Conv2D` + `MaxPooling2D`) pairs, then `Flatten` and 2-3 `Dense` layers. Don't forget about ReLU activations. We also recommend to add `Dropout` to every `Dense` layer (with p from 0.2 to 0.5) to prevent overfitting.

# %%
from keras.models import Sequential
from keras.layers import (
    Conv2D, MaxPooling2D, Flatten,
    Dense, Dropout, BatchNormalization
)
from keras.initializers import GlorotUniform

model = Sequential()

model.add(Conv2D(16, (3,3), padding='same',activation='relu', 
                 input_shape=aug_imgs_train[0].shape))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(32, (3,3), padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.4))
model.add(Dense(128))
model.add(Dropout(0.2))
model.add(Dense(28))

model.summary()
# Define here your model
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 100, 100, 16)      448
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100, 100, 16)      64
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 50, 50, 32)        4640
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 50, 50, 32)        128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               6554112
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 28)                3612
# =================================================================
# Total params: 6,721,276
# Trainable params: 6,721,052
# Non-trainable params: 224
# _________________________________________________________________

# %% [markdown]
# Time to train! Since we are training a regressor, make sure that you use mean squared error (mse) as loss. Feel free to experiment with optimization method (SGD, Adam, etc.) and its' parameters.

# %%
# ModelCheckpoint can be used for saving model during training.
# Saved models are useful for finetuning your model 
# See keras documentation for more info
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.optimizers import SGD, Adam

checkpt = ModelCheckpoint('best_model.h5',save_best_only=True)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10, verbose=1, mode='min')

sgd = SGD(learning_rate=0.001, momentum=0.9, nesterov=False)
adam = Adam(lr=0.001,decay=4e-5)
model.compile(optimizer=adam, loss='mean_squared_error', metrics = ['accuracy'])
model.fit(aug_imgs_train,aug_points_train,epochs=200,batch_size=32,shuffle=True,validation_data=(imgs_val,points_val),
          callbacks=[checkpt,earlystop])
# Choose optimizer, compile model and run training
# Out:
# Epoch 1/200
# 338/338 [==============================] - 80s 238ms/step - loss: 1.1753 - accuracy: 0.0371 - val_loss: 0.0318 - val_accuracy: 0.0683
# Epoch 2/200
# 338/338 [==============================] - 80s 238ms/step - loss: 0.2148 - accuracy: 0.0352 - val_loss: 0.0284 - val_accuracy: 0.0017
# Epoch 3/200
# 338/338 [==============================] - 81s 238ms/step - loss: 0.1097 - accuracy: 0.0279 - val_loss: 0.0185 - val_accuracy: 0.0683
# Epoch 4/200
# 338/338 [==============================] - 80s 237ms/step - loss: 0.0728 - accuracy: 0.0227 - val_loss: 0.0191 - val_accuracy: 0.0683
# Epoch 5/200
# 338/338 [==============================] - 80s 237ms/step - loss: 0.0528 - accuracy: 0.0227 - val_loss: 0.0187 - val_accuracy: 0.0017
# Epoch 6/200
# 338/338 [==============================] - 81s 239ms/step - loss: 0.0408 - accuracy: 0.0196 - val_loss: 0.0180 - val_accuracy: 0.0150
# Epoch 7/200
# 338/338 [==============================] - 82s 243ms/step - loss: 0.0332 - accuracy: 0.0244 - val_loss: 0.0193 - val_accuracy: 0.0150
# Epoch 8/200
# 338/338 [==============================] - 81s 239ms/step - loss: 0.0283 - accuracy: 0.0215 - val_loss: 0.0168 - val_accuracy: 0.0017
# Epoch 9/200
# 338/338 [==============================] - 80s 238ms/step - loss: 0.0251 - accuracy: 0.0256 - val_loss: 0.0189 - val_accuracy: 0.0017
# Epoch 10/200
# 338/338 [==============================] - 80s 237ms/step - loss: 0.0231 - accuracy: 0.0217 - val_loss: 0.0212 - val_accuracy: 0.0017
# Epoch 11/200
# 338/338 [==============================] - 80s 237ms/step - loss: 0.0216 - accuracy: 0.0254 - val_loss: 0.0193 - val_accuracy: 0.0150
# Epoch 12/200
# 338/338 [==============================] - 80s 237ms/step - loss: 0.0208 - accuracy: 0.0238 - val_loss: 0.0192 - val_accuracy: 0.0017
# Epoch 13/200
# 338/338 [==============================] - 80s 237ms/step - loss: 0.0203 - accuracy: 0.0223 - val_loss: 0.0192 - val_accuracy: 0.0150
# Epoch 14/200
# 338/338 [==============================] - 80s 237ms/step - loss: 0.0199 - accuracy: 0.0205 - val_loss: 0.0218 - val_accuracy: 0.0150
# Epoch 15/200
# 338/338 [==============================] - 80s 237ms/step - loss: 0.0198 - accuracy: 0.0177 - val_loss: 0.0166 - val_accuracy: 0.0150
# Epoch 16/200
# 338/338 [==============================] - 80s 236ms/step - loss: 0.0196 - accuracy: 0.0181 - val_loss: 0.0169 - val_accuracy: 0.0150
# Epoch 17/200
# 338/338 [==============================] - 80s 237ms/step - loss: 0.0195 - accuracy: 0.0187 - val_loss: 0.0160 - val_accuracy: 0.0150
# Epoch 18/200
# 338/338 [==============================] - 80s 236ms/step - loss: 0.0196 - accuracy: 0.0189 - val_loss: 0.0203 - val_accuracy: 0.0150
# Epoch 00018: early stopping

# %%
model.save('facical_keypoints_model.h5')

# %%
from keras.models import load_model
model1 = load_model('best_model.h5') #using the best model stored by model checkpoint

# %% [markdown]
# ### Visualize results

# %% [markdown]
# Now visualize neural network results on several images from validation sample. Make sure that your network outputs different points for images (i.e. it doesn't output some constant).

# %%
prediction = model1.predict(imgs_val)

# %%
visualize_points(imgs_val[1],prediction[1])

# %%
visualize_points(imgs_val[200],prediction[200])

# %%
visualize_points(imgs_val[0],prediction[0])

# %%
visualize_points(imgs_val[100],prediction[100])
